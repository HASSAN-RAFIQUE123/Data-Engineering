# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
# connection with mongo db atlas
client=MongoClient("mongodb+srv://hrafiq19hk:H0134440h.@cluster0.zga9xvn.mongodb.net/?retryWrites=true&w=majority")
db=client["wind"]
# add new collection
collection=db["north"]

# %%
collection.count_documents({})
# Out:
# 1051

# %%
data=[
 {
  "original_title": "Delusion",
  "belongs_to_collection": "",
  "homepage": "",
  "_event_time": "2021-04-01T18:34:08.119000Z",
  "overview": "In this fast-paced, noirish road movie, a computer expert embezzles half a million dollars and races off to Reno to start anew. Unfortunately, en route, he picks up a pair of hitchers and ends up entangled with a crazed couple who commandeer his car and leave him alone in the desert to die. As soon as he can, he hits the road to get revenge and to find his money before they do.",
  "poster_path": "/g2o1J0ulttuwovqLc0ho910MR95.jpg",
  "status": "Released",
  "vote_average": 4.8,
  "_id": "5fd124fd5b85548af6a3938a",
  "budget": 1000000,
  "video": "False",
  "imdb_id": "",
  "genres": "[{'id': 80, 'name': 'Crime'}]",
  "tagline": "She only wanted love. But money's better than nothing.",
  "runtime": 100,
  "original_language": "en",
  "_meta": { "mongodb": { "database": "netflix", "collection": "movies" } },
  "production_countries": "[{'iso_3166_1': 'US', 'name': 'United States of America'}]",
  "adult": "False",
  "spoken_languages": "[{'iso_639_1': 'en', 'name': 'English'}]",
  "vote_count": 3,
  "production_companies": "[{'name': 'Cineville', 'id': 2832}]",
  "revenue": 0,
  "popularity": 0.156722,
  "release_date": "1991-06-07",
  "id": 36337,
  "title": "Delusion"
  }
]

# %%
# insert many documebnts in collection
collection.insert_many(data)
# Out:
# InsertManyResult(['5fd124fd5b85548af6a3938a'], acknowledged=True)

# %%
# {
#    status: 'A',
#    $or: [
#      { qty: { $lt: 30 } }, { item: { $regex: '^p' } }
#    ]
# }

# %%
raw=collection.find({})
for data in raw:
  print(data)
# Out:
# {'_id': '5fd124fd5b85548af6a3938a', 'original_title': 'Delusion', 'belongs_to_collection': '', 'homepage': '', '_event_time': '2021-04-01T18:34:08.119000Z', 'overview': 'In this fast-paced, noirish road movie, a computer expert embezzles half a million dollars and races off to Reno to start anew. Unfortunately, en route, he picks up a pair of hitchers and ends up entangled with a crazed couple who commandeer his car and leave him alone in the desert to die. As soon as he can, he hits the road to get revenge and to find his money before they do.', 'poster_path': '/g2o1J0ulttuwovqLc0ho910MR95.jpg', 'status': 'Released', 'vote_average': 4.8, 'budget': 1000000, 'video': 'False', 'imdb_id': '', 'genres': "[{'id': 80, 'name': 'Crime'}]", 'tagline': "She only wanted love. But money's better than nothing.", 'runtime': 100, 'original_language': 'en', '_meta': {'mongodb': {'database': 'netflix', 'collection': 'movies'}}, 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of 
# ...

# %%
data=collection.find({},{"database":"netflix"})
for mydata in data:
  print(mydata)
# Out:
# {'_id': '5fd124fd5b85548af6a3938a', 'database': 'netflix'}

# %% [markdown]
# ## Mongodb Sample Data

# %%
collection.insert_many(
    [
        {
            "item": "canvas",
            "qty": 100,
            "size": {"h": 28, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "journal",
            "qty": 25,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mat",
            "qty": 85,
            "size": {"h": 27.9, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mousepad",
            "qty": 25,
            "size": {"h": 19, "w": 22.85, "uom": "cm"},
            "status": "P",
        },
        {
            "item": "notebook",
            "qty": 50,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "P",
        },
        {
            "item": "paper",
            "qty": 100,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "D",
        },
        {
            "item": "planner",
            "qty": 75,
            "size": {"h": 22.85, "w": 30, "uom": "cm"},
            "status": "D",
        },
        {
            "item": "postcard",
            "qty": 45,
            "size": {"h": 10, "w": 15.25, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketchbook",
            "qty": 80,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketch pad",
            "qty": 95,
            "size": {"h": 22.85, "w": 30.5, "uom": "cm"},
            "status": "A",
        },
    ]
)
# Out:
# InsertManyResult([ObjectId('658f2bbacad3daf94f42a821'), ObjectId('658f2bbacad3daf94f42a822'), ObjectId('658f2bbacad3daf94f42a823'), ObjectId('658f2bbacad3daf94f42a824'), ObjectId('658f2bbacad3daf94f42a825'), ObjectId('658f2bbacad3daf94f42a826'), ObjectId('658f2bbacad3daf94f42a827'), ObjectId('658f2bbacad3daf94f42a828'), ObjectId('658f2bbacad3daf94f42a829'), ObjectId('658f2bbacad3daf94f42a82a')], acknowledged=True)

# %%
s=collection.find({"item":"sketch pad"})

# %%
# print record where size.w is 11

# %%
for ss in s:
  print(ss)
# Out:
# {'_id': ObjectId('658f2bbacad3daf94f42a82a'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}

# %%
# status is A and qty is less then 30
s=collection.find({"status":"A","qty":{"$lt":50}})
for ss in s:
  print(ss)
# Out:
# {'_id': ObjectId('658f2bbacad3daf94f42a822'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('658f2bbacad3daf94f42a828'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}

# %%
# status is A and qty is less then 30 and weight greater then 20
s=collection.find({"status":"A","qty":{"$lt":50},"size.w":{"$gt":20}})
for ss in s:
  print(ss)
# Out:
# {'_id': ObjectId('658f2bbacad3daf94f42a822'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}

# %%
# status is A and qty is less then 30 and size uom is cm
s=collection.find({"status":"A","qty":{"$lt":50},"size.uom":"cm"})
for ss in s:
  print(ss)
# Out:
# {'_id': ObjectId('658f2bbacad3daf94f42a822'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('658f2bbacad3daf94f42a828'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}

# %%
# status is A or B and qty is greater then 60 and size uom is cm
s=collection.find({"$or":[{
    "status":"A"},{"status":"D"}],
                   "qty":{"$gt":60},"size.uom":"cm"})
for ss in s:
  print(ss)
# Out:
# {'_id': ObjectId('658f2bbacad3daf94f42a821'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('658f2bbacad3daf94f42a823'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('658f2bbacad3daf94f42a827'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('658f2bbacad3daf94f42a829'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('658f2bbacad3daf94f42a82a'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}

# %%
# change the status D to A
collection.update_one({"item":"paper"},
                      {"$set":{"status":"A"}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000c6'), 'opTime': {'ts': Timestamp(1703883186, 28), 't': 198}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1703883186, 28), 'signature': {'hash': b'`\xa5>\xab\xb0\xfd\x11\x87\x13\xb3\x18\xd2\x1d\xcc\xd3\x07V\xc2\xf5\x1b', 'keyId': 7280441575035895810}}, 'operationTime': Timestamp(1703883186, 28), 'updatedExisting': True}, acknowledged=True)

# %%
collection.find_one({"item":"paper"})

# %%
# northwind data

# %%
import pprint
import json
from bson.json_util import dumps
from bson import json_util
# import
data=collection.find({"employees.country":"USA"},{'_id':0,"employees.first_name":1,"employees.last_name":1,"employees.city":1,"employees.country":1})
for datas in data:
  # print(dict(datas))
  # print(json(dumps(datas, indent=4, default=json_util.default)))
  pprint.pprint(datas)
  # json.dumps(datas,default=json_util.default)

# %%
# create index
collection.create_index({"employees.name":1})
collection.drop_index("employees.name_1")
collection.create_index({"employees.first_name":1})
# Out:
# 'employees.first_name_1'

# %%
collection=db["northwind"]

# %%
data=collection.find({"country":"USA"})
for datas in data:
  # print(dict(datas))
  # print(json(dumps(datas, indent=4, default=json_util.default)))  pprint.pprint(datas)
#   pprint.pprint(datas)
  print(datas)

# %%
import pprint
# data=collection.find({filter},{select})
data=collection.find({'employees.country':{'$eq':'USA'}},{'employees.first_name':1,'employees.last_name':1,'_id':0})
for datas in data:
  # print(dict(datas))
  # print(json(dumps(datas, indent=4, default=json_util.default)))  pprint.pprint(datas)
  pprint.pprint(datas)

# %%
collection=db["northwind"]

# %%
collection.count_documents({})
# Out:
# 1051

# %%
import pprint
# collection.create_index([('customer.city',1)])
dt=collection.find({'Name':"Beverages"},{'i_d':0})
for data in dt:
#   mydata=data.get("data")
  # print(dict(datas))
  # print(json(dumps(datas, indent=4, default=json_util.default)))
#   pprint.pprint(mydata)
    pprint.pprint(data)
# Out:
# {'@id': 'categories/1-A',
#  '@metadata.@collection': 'Categories',
#  'Description': 'Soft drinks, coffees, teas, beers, and ales',
#  'Name': 'Beverages',
#  '_id': ObjectId('65955b683957a654530734b5')}

# %% [markdown]
# # **Player Data**

# %%
##players data
collection=db["player"]

# %%
collection.count_documents({})
# Out:
# 1034

# %%
# team count
team=collection.distinct('Team')
sum=[]
for teams in team:
  sum.append(teams)
  print(teams)
print("Number of Teams",len(sum))
# Out:
# ANA
# ARZ
# ATL
# BAL
# BOS
# CHC
# CLE
# COL
# CWS
# Cortina Innovation Network
# DET
# FLA
# HOU
# KC
# LA
# MIN
# MLW
# NYM
# NYY
# OAK
# PHI
# PIT
# SD
# SEA
# SF
# STL
# TB
# TEX
# TOR
# WAS
# Number of Teams 30

# %% [markdown]
# ### Aggregation
# db.collection.aggregate(pipeline,option)
# $match/--
# $sort/--
# $avg/--
# $max/min/--
# $sum/--
# $group/--
# $gt/--
# $lt/--

# %%
# team player name with group by team
import pprint
names=collection.aggregate([{'$group':{'_id':'$Team','names_player':{'$push':'$Name'}}}])
for name in names:
  pprint.pprint(name)
# Out:
# {'_id': 'MLW',
#  'names_player': ['Damian Miller',
#                   'Johnny Estrada',
#                   'Mike Rivera',
#                   'J.D. Closser',
#                   'Prince Fielder',
#                   'Rickie Weeks',
#                   'Tony Graffanino',
#                   'Craig Counsell',
#                   'J.J. Hardy',
#                   'Bill Hall',
#                   'Vinny Rottino',
#                   'Corey Koskie',
#                   'Kevin Mench',
#                   'Geoff Jenkins',
#                   'Brady Clark',
#                   'Tony Gwynn Jr.',
#                   'Corey Hart',
#                   'Gabe Gross',
#                   'Laynce Nix',
#                   'Drew Anderson',
#                   'Claudio Vargas',
#                   'Chris Capuano',
#                   'Ben Hendrickson',
#                   'Dave Bush',
#                   'Carlos Villanueva',
#                   'Ben Sheets',
#                   'Jeff Suppan',
# ...

# %%
# all record using Root
names=collection.aggregate([{'$group':{'_id':'$Team','allrecord':{'$push':'$$ROOT'}}}])
for name in names:
  pprint.pprint(name)
# Out:
# Streaming output truncated to the last 5000 lines.
#                 'Position': 'Third Baseman',
#                 'Team': 'KC',
#                 '_id': ObjectId('658e933dc391a7ebaf9d3a6f')},
#                {'Age': 25.84,
#                 'Body - Height(inches)': 70,
#                 'Body - Weight(lbs)': 170,
#                 'Name': 'Joey Gathright',
#                 'Position': 'Outfielder',
#                 'Team': 'KC',
#                 '_id': ObjectId('658e933dc391a7ebaf9d3a70')},
#                {'Age': 27.2,
#                 'Body - Height(inches)': 72,
#                 'Body - Weight(lbs)': 175,
#                 'Name': 'David DeJesus',
#                 'Position': 'Outfielder',
#                 'Team': 'KC',
#                 '_id': ObjectId('658e933dc391a7ebaf9d3a71')},
#                {'Age': 25.22,
#                 'Body - Height(inches)': 72,
#                 'Body - Weight(lbs)': 220,
#                 'Name': 'Shane Costa',
# ...

# %%
# count name of player who are in COL team
names=collection.find({'Team':'COL'},{'Name':1,'_id':0})
for name in names:
  pprint.pprint(name)
# Out:
# {'Name': 'Yorvit Torrealba'}
# {'Name': 'Chris Iannetta'}
# {'Name': 'Alvin Colina'}
# {'Name': 'Todd Helton'}
# {'Name': 'Jamey Carroll'}
# {'Name': 'Kaz Matsui'}
# {'Name': 'Troy Tulowitzki'}
# {'Name': 'Clint Barmes'}
# {'Name': 'Garrett Atkins'}
# {'Name': 'Ryan Spilborghs'}
# {'Name': 'Cory Sullivan'}
# {'Name': 'Jeff Salazar'}
# {'Name': 'Willy Taveras'}
# {'Name': 'Matt Holliday'}
# {'Name': 'Brad Hawpe'}
# {'Name': 'Jeff Baker'}
# {'Name': 'Javy Lopez'}
# {'Name': 'Byung-Hyun Kim'}
# {'Name': 'Rodrigo Lopez'}
# {'Name': 'Brian Lawrence'}
# {'Name': 'Josh Fogg'}
# {'Name': 'Aaron Cook'}
# {'Name': 'Denny Bautista'}
# {'Name': 'Ubaldo Jimenez'}
# {'Name': 'Jason Hirsh'}
# {'Name': 'Jeff Francis'}
# {'Name': 'Taylor Buchholz'}
# {'Name': 'Ryan Speier'}
# {'Name': 'Ramon Ramirez'}
# {'Name': 'Manny Corpas'}
# {'Name': 'Juan Morillo'}
# {'Name': 'Brian Fuentes'}
# {'Name': 'LaTroy Hawkins'}
# {'Name': 'Tom Martin'}
# {'Name': 'Jeremy Affeldt'}

# %%
# count  of player in COL team
names=collection.count_documents({'Team':'COL'})
print(names)
# Out:
# 35

# %%
# change the name of Cortina Innovation Network to CIN
collection.update_many({'Team':'Cortina Innovation Network'},{'$set':{'Team':'CIN'}})

# %%
# total player  in  Teams
names=collection.aggregate([{'$group':{'_id':'$Team','Total':{'$sum':1}}}])
for name in names:
  pprint.pprint(name)
# Out:
# {'Total': 33, '_id': 'CWS'}
# {'Total': 28, '_id': 'ARZ'}
# {'Total': 37, '_id': 'DET'}
# {'Total': 33, '_id': 'MIN'}
# {'Total': 36, '_id': 'CIN'}
# {'Total': 32, '_id': 'STL'}
# {'Total': 38, '_id': 'NYM'}
# {'Total': 37, '_id': 'OAK'}
# {'Total': 33, '_id': 'TB'}
# {'Total': 36, '_id': 'PHI'}
# {'Total': 34, '_id': 'TOR'}
# {'Total': 35, '_id': 'KC'}
# {'Total': 35, '_id': 'COL'}
# {'Total': 33, '_id': 'LA'}
# {'Total': 34, '_id': 'SEA'}
# {'Total': 35, '_id': 'MLW'}
# {'Total': 33, '_id': 'SD'}
# {'Total': 34, '_id': 'SF'}
# {'Total': 35, '_id': 'CLE'}
# {'Total': 36, '_id': 'BOS'}
# {'Total': 35, '_id': 'BAL'}
# {'Total': 35, '_id': 'ANA'}
# {'Total': 32, '_id': 'FLA'}
# {'Total': 37, '_id': 'ATL'}
# {'Total': 35, '_id': 'TEX'}
# {'Total': 36, '_id': 'WAS'}
# {'Total': 36, '_id': 'CHC'}
# {'Total': 34, '_id': 'HOU'}
# {'Total': 35, '_id': 'PIT'}
# {'Total': 32, '_id': 'NYY'}

# %%
# Max number of player team
names=collection.aggregate([{'$group':{'_id':'$Team','Total':{'$sum':1}}},{'$sort':{'Total':-1}},{'$limit':1}])
for name in names:
  pprint.pprint(name)
# Out:
# {'Total': 38, '_id': 'NYM'}

# %%
# Minimum number of player team
names=collection.aggregate([{'$group':{'_id':'$Team','Total':{'$sum':1}}},{'$sort':{'Total':1}},{'$limit':1}])
for name in names:
  pprint.pprint(name)
# Out:
# {'Total': 28, '_id': 'ARZ'}

# %%
names=collection.find({'Name':'Paul Bako'})
for name in names:
  pprint.pprint(name)
# Out:
# {'Age': 34.69,
#  'Body - Height(inches)': 74,
#  'Body - Weight(lbs)': 215,
#  'Name': 'Paul Bako',
#  'Position': 'Catcher',
#  'Team': 'BAL',
#  '_id': ObjectId('658e933dc391a7ebaf9d390c')}

# %%
# avg_weight by each team
names=collection.aggregate([{'$group':{'_id':'$Team','avgweight':{'$avg':'$Body - Weight(lbs)'}}}])
for name in names:
  pprint.pprint(name)
# Out:
# {'_id': 'ANA', 'avgweight': 201.0857142857143}
# {'_id': 'BAL', 'avgweight': 196.34285714285716}
# {'_id': 'CLE', 'avgweight': 201.65714285714284}
# {'_id': 'BOS', 'avgweight': 204.83333333333334}
# {'_id': 'SF', 'avgweight': 202.7941176470588}
# {'_id': 'SD', 'avgweight': 203.75757575757575}
# {'_id': 'MLW', 'avgweight': 205.28571428571428}
# {'_id': 'CWS', 'avgweight': 210.5151515151515}
# {'_id': 'ARZ', 'avgweight': 208.07142857142858}
# {'_id': 'NYY', 'avgweight': 208.3125}
# {'_id': 'CHC', 'avgweight': 204.13888888888889}
# {'_id': 'HOU', 'avgweight': 198.05882352941177}
# {'_id': 'TEX', 'avgweight': 202.6}
# {'_id': 'WAS', 'avgweight': 199.75}
# {'_id': 'ATL', 'avgweight': 199.51351351351352}
# {'_id': 'PIT', 'avgweight': 204.37142857142857}
# {'_id': 'FLA', 'avgweight': 202.375}
# {'_id': 'TB', 'avgweight': 197.45454545454547}
# {'_id': 'OAK', 'avgweight': 198.97297297297297}
# {'_id': 'NYM', 'avgweight': 197.21052631578948}
# {'_id': 'STL', 'avgweight': 201.625}
# ...

# %%
# Team who have Heaviest Player
names=collection.aggregate([{'$group':{'_id':'$Team','max_avgweight':{'$avg':'$Body - Weight(lbs)'}}},{'$sort':{'avgweight':-1}},{'$limit':1}])
for name in names:
  pprint.pprint(name)
# Out:
# {'_id': 'CLE', 'max_avgweight': 201.65714285714284}

# %%
# all record of Maximum weight Player
names=collection.aggregate([{'$sort':{'Body - Weight(lbs)':-1}},{'$limit':1}])
for name in names:
  pprint.pprint(name)
# Out:
# {'Age': 26.61,
#  'Body - Height(inches)': 79,
#  'Body - Weight(lbs)': 290,
#  'Name': 'C.C. Sabathia',
#  'Position': 'Starting Pitcher',
#  'Team': 'CLE',
#  '_id': ObjectId('658e933dc391a7ebaf9d39aa')}

# %%
# Team who have Heaviest Player
names=collection.aggregate([{'$group':{'_id':'$Team','avgweight':{'$max':'$Body - Weight(lbs)'}}},{'$sort':{'avgweight':-1}},{'$limit':1}])
for name in names:
  pprint.pprint(name)
# Out:
# {'_id': 'CLE', 'avgweight': 290}

# %% [markdown]
# ## Indexing

# %%
collection.create_index({'Name':1})
# Out:
# 'Name_1'

# %%
collection.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'Name_1': {'v': 2, 'key': [('Name', 1)]}}

# %%
from sys import executable
query={'Name':'Chris Gomez'}
names=collection.find(query).explain()
names

# results:
# 'inputStage': {'stage': 'IXSCAN',
#     'nReturned': 1,
#  'totalDocsExamined': 1,
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'test_data.player',
#   'indexFilterSet': False,
#   'parsedQuery': {'Name': {'$eq': 'Chris Gomez'}},
#   'queryHash': 'C2E834E8',
#   'planCacheKey': '3323D277',
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'winningPlan': {'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'Name': 1},
#     'indexName': 'Name_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'Name': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'Name': ['["Chris Gomez", "Chris Gomez"]']}}},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
#   'nReturned': 1,
#   'executionTimeMillis': 0,
#   'totalKeysExamined': 1,
#   'totalDocsExamined': 1,
#   'executionStages': {'stage': 'FETCH',
#    'nReturned': 1,
# ...

# %% [markdown]
# ## NorthWind Data

# %%
product=db['products']

# %%
results=product.find({},{'Name':1,'Category':1,'_id':0})
for result in results:
#   for product in result.get('Name',[]):
#     print(product)
#   pprint.pprint(name)
    print(result)
# names
results=categories.find({},{'Name':1,'@id':1,'_id':0})
for result in results:
#   for product in result.get('Name',[]):
#     print(product)
#   pprint.pprint(name)
    print(result)
# names
# Out:
# {'Name': 'Chai', 'Category': 'categories/1-A'}
# {'Name': 'Chang', 'Category': 'categories/1-A'}
# {'Name': 'Aniseed Syrup', 'Category': 'categories/2-A'}
# {'Name': "Chef Anton's Cajun Seasoning", 'Category': 'categories/2-A'}
# {'Name': "Chef Anton's Gumbo Mix", 'Category': 'categories/2-A'}
# {'Name': "Grandma's Boysenberry Spread", 'Category': 'categories/2-A'}
# {'Name': "Uncle Bob's Organic Dried Pears", 'Category': 'categories/7-A'}
# {'Name': 'Northwoods Cranberry Sauce', 'Category': 'categories/2-A'}
# {'Name': 'Mishi Kobe Niku', 'Category': 'categories/6-A'}
# {'Name': 'Ikura', 'Category': 'categories/8-A'}
# {'Name': 'Queso Cabrales', 'Category': 'categories/4-A'}
# {'Name': 'Queso Manchego La Pastora', 'Category': 'categories/4-A'}
# {'Name': 'Konbu', 'Category': 'categories/8-A'}
# {'Name': 'Tofu', 'Category': 'categories/7-A'}
# {'Name': 'Genen Shouyu', 'Category': 'categories/2-A'}
# {'Name': 'Pavlova', 'Category': 'categories/3-A'}
# ...

# %%
pipeline = [
    {
        "$lookup": {
            "from": "category",
            "localField": "Category",
            "foreignField": "@id",
            "as": "category_info"
        }
    },
    {
        "$unwind": "$category_info"
    },
    {
        "$project": {
            "_id": 0,
            "Product_Name": "$Name",
            "Category_Name": "$category_info.Name"
        }
    }
]

result = list(product.aggregate(pipeline))

for item in result:
    print(f"Product: {item['Product_Name']} - Category: {item['Category_Name']}")
# Out:
# Product: Chai - Category: Beverages
# Product: Chang - Category: Beverages
# Product: Aniseed Syrup - Category: Condiments
# Product: Chef Anton's Cajun Seasoning - Category: Condiments
# Product: Chef Anton's Gumbo Mix - Category: Condiments
# Product: Grandma's Boysenberry Spread - Category: Condiments
# Product: Uncle Bob's Organic Dried Pears - Category: Produce
# Product: Northwoods Cranberry Sauce - Category: Condiments
# Product: Mishi Kobe Niku - Category: Meat/Poultry
# Product: Ikura - Category: Seafood
# Product: Queso Cabrales - Category: Dairy Products
# Product: Queso Manchego La Pastora - Category: Dairy Products
# Product: Konbu - Category: Seafood
# Product: Tofu - Category: Produce
# Product: Genen Shouyu - Category: Condiments
# Product: Pavlova - Category: Confections
# Product: Alice Mutton - Category: Meat/Poultry
# Product: Carnarvon Tigers - Category: Seafood
# Product: Teatime Chocolate Biscuits - Category: Confections
# ...

# %%
# lookup table base on ID
pipeline = [
    {
        "$lookup": {
            "from": "category",
            "localField": "Category",
            "foreignField": "@id",
            "as": "category_info"
        }
    }
#     {
#         "$unwind": "$category_info"
#     },
#     {
#         "$project": {
#             "_id": 0,
#             "Product_Name": "$Name",
#             "Category_Name": "$category_info.Name"
#         }
#     }
]

result = list(product.aggregate(pipeline))

for item in result:
#     print(f"Product: {item['Product_Name']} - Category: {item['Category_Name']}")
      pprint.pprint(item)
# Out:
# {'@id': 'products/1-A',
#  '@metadata.@collection': 'Products',
#  '@metadata.@timeseries': ['INC:Views'],
#  'Category': 'categories/1-A',
#  'Discontinued': 'False',
#  'Name': 'Chai',
#  'PricePerUnit': 18,
#  'QuantityPerUnit': '10 boxes x 20 bags',
#  'ReorderLevel': 10,
#  'Supplier': 'suppliers/1-A',
#  'UnitsInStock': 1,
#  'UnitsOnOrder': 39,
#  '_id': ObjectId('659565eb3957a65453395e24'),
#  'category_info': [{'@id': 'categories/1-A',
#                     '@metadata.@collection': 'Categories',
#                     'Description': 'Soft drinks, coffees, teas, beers, and '
#                                    'ales',
#                     'Name': 'Beverages',
#                     '_id': ObjectId('659566b53957a654533d2620')}]}
# {'@id': 'products/2-A',
#  '@metadata.@collection': 'Products',
#  '@metadata.@timeseries': ['INC:Views'],
#  'Category': 'categories/1-A',
#  'Discontinued': 'False',
#  'Name': 'Chang',
#  'PricePerUnit': 19,
# ...

# %%
categories=db['category']

# %%
results=categories.find({},{'Name':1,'@id':1,'_id':0})
for result in results:
#   for product in result.get('Name',[]):
#     print(product)
#   pprint.pprint(name)
    print(result)
# names
# Out:
# {'@id': 'categories/1-A', 'Name': 'Beverages'}
# {'@id': 'categories/2-A', 'Name': 'Condiments'}
# {'@id': 'categories/3-A', 'Name': 'Confections'}
# {'@id': 'categories/4-A', 'Name': 'Dairy Products'}
# {'@id': 'categories/5-A', 'Name': 'Grains/Cereals'}
# {'@id': 'categories/6-A', 'Name': 'Meat/Poultry'}
# {'@id': 'categories/7-A', 'Name': 'Produce'}
# {'@id': 'categories/8-A', 'Name': 'Seafood'}

# %%
import pprint
results=product.find({},{'@id','Name'})
for result in results:
  pprint.pprint(result)
# Out:
# {'@id': 'products/1-A',
#  'Name': 'Chai',
#  '_id': ObjectId('659565eb3957a65453395e24')}
# {'@id': 'products/2-A',
#  'Name': 'Chang',
#  '_id': ObjectId('659565eb3957a65453395e25')}
# {'@id': 'products/3-A',
#  'Name': 'Aniseed Syrup',
#  '_id': ObjectId('659565eb3957a65453395e26')}
# {'@id': 'products/4-A',
#  'Name': "Chef Anton's Cajun Seasoning",
#  '_id': ObjectId('659565eb3957a65453395e27')}
# {'@id': 'products/5-A',
#  'Name': "Chef Anton's Gumbo Mix",
#  '_id': ObjectId('659565eb3957a65453395e28')}
# {'@id': 'products/6-A',
#  'Name': "Grandma's Boysenberry Spread",
#  '_id': ObjectId('659565eb3957a65453395e29')}
# {'@id': 'products/7-A',
#  'Name': "Uncle Bob's Organic Dried Pears",
#  '_id': ObjectId('659565eb3957a65453395e2a')}
# {'@id': 'products/8-A',
#  'Name': 'Northwoods Cranberry Sauce',
#  '_id': ObjectId('659565eb3957a65453395e2b')}
# {'@id': 'products/9-A',
#  'Name': 'Mishi Kobe Niku',
#  '_id': ObjectId('659565eb3957a65453395e2c')}
# {'@id': 'products/10-A',
# ...

# %%
import pprint
results=collection.find_one({'products.product_id':14},{'_id':0,"products.product_name":1})
for result in results:
  print(result)
# Out:
# products

# %%
# how many tofu sale: product_id is 14
#order_details
# sum of quantity where .order_details.product.id=14
results=product.aggregate([{"$match":{'Name':'Tofu'}},
                      {'$group':{'_id':None,'t_sale':{'$sum':'$UnitsOnOrder'}}}
                      ]
                     )
for result in results:
  pprint.pprint(result)
# Out:
# {'_id': None, 't_sale': 35}

# %%
# test question
# name of product with their categories
results=collection.find({},{'products.product_name','categories.category_name'})
for result in results:
  # for product in result.get('products',[]):
   for category in result.get('categories',[]):

        print(product,category)
  # print(result)
# Out:
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Beverages'}
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Condiments'}
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Confections'}
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Dairy Products'}
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Grains/Cereals'}
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Meat/Poultry'}
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Produce'}
# {'product_name': 'Original Frankfurter grüne Soße'} {'category_name': 'Seafood'}

# %%
# Create index that will allow to search employees by the name of their superior.
# (For example the index for query:
# from index '...' where BossName == 'Buchanan')
# # Write the full index syntax.
collection.create_index('employees.reports_to')
# Out:
# 'employees.reports_to_1'

# %%
# names=collection.aggregate([{'$group':{'_id':'$Team','avgweight':{'$max':'$Body - Weight(lbs)'}}},{'$sort':{'avgweight':-1}},{'$limit':1}])
results=collection.find({'employees.reports_to':{'$eq':5}},{'employees.first_name':1})
for result in results:
  pprint.pprint(result)
# Out:
# {'_id': ObjectId('65902e2ac391a7ebaf31606f'),
#  'employees': [{'first_name': 'Nancy'},
#                {'first_name': 'Andrew'},
#                {'first_name': 'Janet'},
#                {'first_name': 'Margaret'},
#                {'first_name': 'Steven'},
#                {'first_name': 'Michael'},
#                {'first_name': 'Robert'},
#                {'first_name': 'Laura'},
#                {'first_name': 'Anne'}]}
